# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)
print(response['messages'][0].content)
print(response['messages'][1].content)
print(response)
# Out:
# What's the capital of the moon?
# There isn’t one. The Moon has no government or administrative divisions, so no capital. If future lunar settlements are established, a “capital” would just be whatever organization running the base designates, but none exists today.
# {'messages': [HumanMessage(content="What's the capital of the moon?", additional_kwargs={}, response_metadata={}, id='118d6690-34c6-4db7-ac6d-169c56915fce'), AIMessage(content='There isn’t one. The Moon has no government or administrative divisions, so no capital. If future lunar settlements are established, a “capital” would just be whatever organization running the base designates, but none exists today.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 630, 'prompt_tokens': 13, 'total_tokens': 643, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DxyL0PWK6XU8GJvfuLSlZLKed1myN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f2e25-d705-7f51-a0c5-afdd6e859e6d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 630, 'total_tokens': 643, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this sci‑fi world, the Moon’s capital is Lunopolis.
#
# - Where it sits: Along the rim of Shackleton Crater at the lunar south pole, where a web of lava-tube caverns and crater terraces has been transformed into a seamless cityscape. Sunlight dances off glassy domes, while shield rings and artificial auroras give it a constant, otherworldly glow.
#
# - Government: A Lunar Assembly governs Lunopolis, with representatives from districts carved into the crater rim and the tunnel suburbs. The council’s work is augmented by a council of scientists and a rotating Earth-Prime liaison to keep Earth and Moon policy aligned.
#
# - Architecture and daily life: A grand lattice of interconnected domes, glass towers, and pressurized tunnels. Homes and offices blend into the rock, with hydroponic gardens climbing the walls. Transit runs on mag-lev rails and airless-suit corridors; residents move with ease in low gravity, courtesy of grav-shoes and magnetic rails.
#
# - Economy: Powered by solar harvest, helium-3 fusion research, and ice mined from shadowed craters. Lunopolis is a hub for lunar science, mining technology, and lunar-tourism—think glass observatories, crater markets, and research outposts.
#
# - Landmarks:
#   - The Lantern Spire: a towering observatory and solar-energy nexus whose crown blooms with lights at lunar dusk.
#   - The Ice Garden: a crystalline greenhouse carved into a lava-tube, home to hardy lunar flora.
#   - The Glass Cathedral: a sanctum of quiet reflection built from translucent basalt and silica glass.
#   - The Helium Atrium: a vast atrium where researchers demonstrate microgravity experiments in a controlled bubble of air.
#
# - Culture: A blend of scientific curiosity and art. Festivals celebrate Earthrise, the first contact anniversaries, and exhibitions of gravity-defying dance in the low-gravity squares.
#
# If you’d like, I can tailor Lunopolis further (name variations, district map, a day-in-the-life scene, or a political intrigue arc). Would you prefer a grittier frontier vibe or a gleaming, utopian metropolis?

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]

# %%
response["structured_response"].name

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
