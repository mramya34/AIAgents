# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon has no government or capital city, and it’s not permanently inhabited.\n\nIf you’re asking for a fictional idea (for a story or game), here are a few quick options:\n- Lunaris Prime: a domed metropolis on the near side’s equator, governed by an international lunar council.\n- Selene City: a polar hub near Shackleton crater focused on water ice, serving as the lunar federation’s capital.\n- Asteria: a technologically advanced capital located in Mare Serenitatis, with orbital governance and surface administration.\n\nWant me to tailor a fictional capital to a specific setting or vibe?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1289, 'prompt_tokens': 13, 'total_tokens': 1302, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1152, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dv4Deew5l9uggJwy4osTbdCxVqg8f', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f04e1-0778-79f0-9642-c849dbb4e615-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 1289, 'total_tokens': 1302, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1152}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon has no government or capital city, and it’s not permanently inhabited.
#
# If you’re asking for a fictional idea (for a story or game), here are a few quick options:
# - Lunaris Prime: a domed metropolis on the near side’s equator, governed by an international lunar council.
# - Selene City: a polar hub near Shackleton crater focused on water ice, serving as the lunar federation’s capital.
# - Asteria: a technologically advanced capital located in Mare Serenitatis, with orbital governance and surface administration.
#
# Want me to tailor a fictional capital to a specific setting or vibe?

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-Dv4Deew5l9uggJwy4osTbdCxVqg8f',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 1289,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 1152,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 1302}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon has no government or cities, so it has no capital. If you’re thinking of a fictional world or a future scenario, tell me the setting and I can help suggest a capital name.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[14], line 3
#       1 model = init_chat_model(model="claude-sonnet-4-5")
# ----> 3 response = model.invoke("What's the capital of the Moon?")
#       4 print(response.content)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1766, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1764 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1765 try:
# -> 1766     data = self._create(payload)
#    1767 except anthropic.BadRequestError as e:
#    1768     _handle_anthropic_bad_request(e)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1431, in ChatAnthropic._create(self, payload)
#    1429 if "betas" in payload:
#    1430     return self._client.beta.messages.create(**payload)
# -> 1431 return self._client.messages.create(**payload)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:1018, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    1011 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    1012     warnings.warn(
#    1013         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1014         UserWarning,
#    1015         stacklevel=3,
#    1016     )
# -> 1018 return self._post(
#    1019     "/v1/messages",
#    1020     body=maybe_transform(
#    1021         {
#    1022             "max_tokens": max_tokens,
#    1023             "messages": messages,
#    1024             "model": model,
#    1025             "cache_control": cache_control,
#    1026             "container": container,
#    1027             "inference_geo": inference_geo,
#    1028             "metadata": metadata,
#    1029             "output_config": output_config,
#    1030             "service_tier": service_tier,
#    1031             "stop_sequences": stop_sequences,
#    1032             "stream": stream,
#    1033             "system": system,
#    1034             "temperature": temperature,
#    1035             "thinking": thinking,
#    1036             "tool_choice": tool_choice,
#    1037             "tools": tools,
#    1038             "top_k": top_k,
#    1039             "top_p": top_p,
#    1040         },
#    1041         message_create_params.MessageCreateParamsStreaming
#    1042         if stream
#    1043         else message_create_params.MessageCreateParamsNonStreaming,
#    1044     ),
#    1045     options=make_request_options(
#    1046         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1047     ),
#    1048     cast_to=Message,
#    1049     stream=stream or False,
#    1050     stream_cls=Stream[RawMessageStreamEvent],
#    1051 )
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# AuthenticationError: Error code: 401 - {'type': 'error', 'error': {'type': 'authentication_error', 'message': 'invalid x-api-key'}, 'request_id': 'req_011CcSFs9yah493EGSzYoZdn'}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3047, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3046 try:
# -> 3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\google\genai\models.py:5709, in Models.generate_content(self, model, contents, config)
#    5708 i += 1
# -> 5709 response = self._generate_content(
#    5710     model=model, contents=contents, config=parsed_config
#    5711 )
#    5713 function_map = _extra_utils.get_function_map(parsed_config)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\google\genai\models.py:4371, in Models._generate_content(self, model, contents, config)
#    4369 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4371 response = self._api_client.request(
#    4372     'post', path, request_dict, http_options
#    4373 )
#    4375 if config is not None and getattr(
#    4376     config, 'should_return_http_response', None
#    4377 ):
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\google\genai\_api_client.py:1401, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1398 http_request = self._build_request(
#    1399     http_method, path, request_dict, http_options
#    1400 )
# -> 1401 response = self._request(http_request, http_options, stream=False)
#    1402 response_body = (
#    1403     response.response_stream[0] if response.response_stream else ''
#    1404 )
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\google\genai\_api_client.py:1235, in BaseApiClient._request(self, http_request, http_options, stream)
#    1234     retry = tenacity.Retrying(**retry_kwargs)
# -> 1235     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1237 return self._retry(self._request_once, http_request, stream)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\google\genai\_api_client.py:1214, in BaseApiClient._request_once(self, http_request, stream)
#    1207 response = self._httpx_client.request(
#    1208     method=http_request.method,
#    1209     url=http_request.url,
#    (...)   1212     timeout=http_request.timeout,
#    1213 )
# -> 1214 errors.APIError.raise_for_response(response)
#    1215 return HttpResponse(
#    1216     response.headers, response if stream else [response.text]
#    1217 )
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\google\genai\errors.py:134, in APIError.raise_for_response(cls, response)
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\google\genai\errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[15], line 5
#       1 from langchain_google_genai import ChatGoogleGenerativeAI
#       3 model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
# ----> 5 response = model.invoke("What's the capital of the Moon?")
#       6 print(response.content)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2535, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2532         msg = "Tools are already defined.code_execution tool can't be defined"
#    2533         raise ValueError(msg)
# -> 2535 return super().invoke(input, config, stop=stop, **kwargs)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3051, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
# -> 3051     _handle_client_error(e, request)
#    3053 return _response_to_result(response)
#
# File C:\LANGCHAINTUTORIAL\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:145, in _handle_client_error(e, request)
#     143 model_name = request.get("model", "unknown")
#     144 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 145 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash-lite' (INVALID_ARGUMENT): 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='f3a45276-250f-4f32-b0e1-c8e267e4c23a'),
#               AIMessage(content='There isn’t one. The Moon has no government or political subdivisions, so it doesn’t have a capital. If you’re thinking of a fictional lunar colony, some stories do assign capitals to their lunar cities—tell me which work and I can name it.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 509, 'prompt_tokens': 13, 'total_tokens': 522, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dv4Z3935t6rjwLL2VKBUWfuGgO6Nq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f04f5-4b2a-73d2-862f-a2098b9163c7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 509, 'total_tokens': 522, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon has no government or political subdivisions, so it doesn’t have a capital. If you’re thinking of a fictional lunar colony, some stories do assign capitals to their lunar cities—tell me which work and I can name it.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='5fefe0e4-ec4a-461a-bdcd-fab706ab6d33'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='00d154b9-041c-474d-9f52-ffaf75eedacf', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='bbb7e9ff-b7ba-4eb4-a096-ba55f922bc70'),
#               AIMessage(content='Just a heads-up: there isn’t a real capital on the Moon. Luna City is a fictional creation you can use for stories, games, or worldbuilding. If you’re game, here’s a richly detailed take you can drop into a sci‑fi setting.\n\nPremise\n- Luna City is the capital of a United Lunar Republic (ULR), founded after a global treaty that merged multiple space agencies and private powers into a single lunar government.\n- It sits at the rim of Shackleton Crater, where sunlit cliffs meet shadowed floors and abundant ice can be accessed for water and air processing.\n- The city is a network of pressurized domes and tunnels linked by vacuum rails, hover tubes, and subterranean transit.\n\nCity layout and key districts\n- Central Dome District: The political heart with the Grand Assembly Hall, the Glass Spire (a translucent city symbol and weather monitoring hub), and the bureaucratic spine that runs beneath the domes.\n- Residential Arcologies: Layered habitats with rotating gravity sections to simulate Earth-like days; family neighborhoods mix with temporary worker housing.\n- Science & Education Quarter: Lunar University, ISRU (in-situ resource utilization) labs, cryogenic research facilities, and open-plan collaboration studios.\n- Ice & Water District: Facilities for ice mining, water purification, oxygen generation, and the city’s hydroponic farms. Security is tight around the ice deposits.\n- Port & Logistics Terminal: Spaceport, cargo docks, and maintenance yards for lunar shuttles, cargo landers, and rovers.\n- Cultural Quarter: Museums, theaters, art studios, Gravity Park (a low-gravity recreation zone), and a festival maze for solstice events.\n- Corporate Row: HQs of major mining, energy, and tech firms that operate in partnership with the government. A delicate balance exists between public policy and private interests.\n\nGovernance and society\n- Government: A Lunar Council represents member states and major corporations, supported by ministries for Resources, Security, Science, Education, Health, and Culture. The Premier chairs the Council but must rely on cross-party consensus to pass major legislation.\n- Law and order: A mixed police-military force called the Lunar Guard handles border security, orbital defense coordination, and civil emergencies within the domes.\n- Population and culture: A multinational, multilingual society with engineers, scientists, miners, and artists. Life is highly regulated for safety and efficiency, but the city fosters bold experimentation in design, art, and space science.\n- Timekeeping: A standard lunar time (sol) system with synchronized schedules to coordinate Earth-lunar tie-ins; local cycles adjust for solar exposure in different districts.\n\nInfrastructure and technology\n- Habitat and energy: Pressure domes with regolith shielding, air recycling plants, and hydroponic gardens to feed the population. Solar farms on crater rims and modular nuclear microreactors provide power.\n- Transport: \n  - Subsurface mag-lev tubes for rapid movement between districts.\n  - Vacuum rail corridors and hover trampolines for short hops.\n  - Personal air-dams and mobility units for excursions in outside zones of the Dome Complex.\n- Life support: Closed-loop air processing, water recycling, and waste-to-resource facilities. ISRU converts ice into breathable air, drinking water, and oxidizer for propulsion.\n- Health and science: Zero-gravity gyms, medical bays with telepresence diagnostics, and cryo-chambers for long-term research or patient recovery.\n\nDaily life and culture\n- Work life centers on collaboration and safety. Residents often rotate between lab shifts, fieldwork in ice mining, and public service duties.\n- Food comes from hydroponic farms and imported raw materials transformed into meals in smart kitchens. Menus emphasize nutrient balance and energy efficiency.\n- Education emphasizes STEM, space ethics, and multicultural studies; storytelling and art c ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is not a real place on the Moon, but a rich, customizable setting you can use for sci‑fi fiction, world-building games, or thought experiments. Below is a detailed, self-contained proposal for Luna City as the capital of a lunar polity. You can take any part of this and remix it to fit hard sci‑fi, cyberpunk, utopian, or dystopian tones.
#
# Overview
# - Name and role: Luna City is the political, economic, and cultural capital of the Moon. It hosts the main lunar government, key research institutions, major corporations with lunar operations, and the central trade and media hubs that connect Earth, the Moon, and beyond.
# - Political status: The Moon is governed by a constitutional lunar federation/league (for example, the United Lunar Commonwealth or Lunar Confederation) with Luna City as the seat of the World Council of Moon Affairs. It is a hub of diplomacy, law, and policy coordination among lunar settlements, Earth governments, and orbital stations.
# - Identity: Luna City is known for its stark contrast of glass-and-steel megastructures and shielded, subterranean districts. It prides itself on engineering ingenuity, sustainable lifeways in vacuum, and a culture that blends Earth legacies with lunar adaptation.
#
# Geography and Setting
# - Location: A sheltered basin on the lunar surface near a water-ice reservoir (often described as a southern polar region site) or, for a more Earth-like feel, a crater rim complex that receives long intervals of sunlight but sits above permanently shadowed zones to exploit ice resources.
# - Topography: The city expansion is multi-layered: a shielded, underground core for life support and manufacturing; mid-level settlements connected by pressurized transit tubes; and an outer layer of surface vantages, solar farms, and landing pads.
# - Climate and environment: Outside is vacuum with extreme temperatures. Inside, air, water, and oxygen are recycled; radiation shielding is provided by thick regolith shells, magnetic shielding, and subterranean volumes. The city enjoys abundant solar power and, where needed, compact nuclear or fusion microreactors for energy resilience.
#
# Government and politics
# - Core governance: A bicameral or tri-cameral system anchored by a Lunar Council (representing lunar districts), an Executive Office (Prime Secretary or Chancellor), and an independent Judiciary. There is a Charter of the Moon that guarantees resource rights, habitat standards, and planetary cooperation.
# - Elections and representation: Luna City uses a combination of district representation (for lunar settlements) and technocratic appointments for strategic agencies (energy, water, life support, research). There are term limits and a rotating leadership council to avoid entrenched power.
# - Interplanetary relations: Luna City negotiates with Earth governments, spacefaring corporations, and neighboring orbital authorities. It hosts the Lunar Assembly, a periodic summit that harmonizes policy on mining, research ethics, space traffic, and defense.
# - Law and order: A Lunar Authority oversees civil law, while a dedicated Defense and Security Directorate manages protection against micrometeoroids, radiation events, cyber threats, and civil unrest. Privacy laws and resource rights are central legal pillars.
#
# Economy and infrastructure
# - Core industries:
#   - Energy: Solar fields around the city, supported by compact fusion or fission microreactors for continuity through the long lunar night.
#   - Water and life support: Water ice is mined and electrolyzed to provide breathable air and hydrogen fuel. Closed-loop agriculture sustains food supply.
#   - Manufacturing and research: Additive manufacturing (3D printing) of tools, habitat parts, and medical devices; advanced materials derived from regolith.
#   - Services and governance: Digital governance, finance, education, media, and culture engines.
# - Currency and trade: A lunar currency or a digital blockchain-based credit system (LunaCred or LunaCoin) facilitates intra-moon and Earth-more trading. Trade with Earth focuses on high-value components: optics, sensors, delicate alloys, and agricultural tech.
# - Transportation of goods: Ground transport uses pressurized tramways, maglev-like tubes, and autonomous rovers. Spaceport facilities handle interplanetary arrivals and orbital transfers, with landing pads and orbital elevators as optional concepts depending on the tech level.
#
# Architecture and urban design
# - Aesthetic: A blend of high-tech futurism and rugged utilitarianism. Architecture emphasizes radiation shielding, modular growth, and rapid reconfiguration. Transparent polymerics and smart-glass facades that adapt to sun angles dominate the surface layer, while subterranean layers use reinforced carbon-based composites and basalt or regolith concretes.
# - Districts:
#   - Central Accords Plaza: The political heart with the Council Chambers, press centers, and citizen consults.
#   - The Shield Dome District: A ring of radiation-shielded habitats and laboratories with panoramic views into the surface and beyond.
#   - Oasis Greenhouse Sector: Complex agricultural domes that supply fresh produce to the city.
#   - Archive and Learning Quarter: Universities, think tanks, and digital libraries; heavily networked with Earth institutions.
#   - Industrial Enclave: Manufacturing, repair yards, and robotics hubs; warehouses and logistics spine.
#   - Night Market and Cultural Quarter: Food stalls, theaters, museums, and clubs offering lunar-themed entertainment and Earth-inspired culture.
# - Public spaces: Light-lit boulevards, solar canopies that store energy for night illumination, and shaded plazas to reduce dust accumulation on surfaces.
#
# Science, technology, and daily life
# - Core tech:
#   - In-situ resource utilization (ISRU): regolith processing, water extraction, oxygen generation.
#   - Habitat tech: inflatable and rigid habitats with regenerative life support; autonomous maintenance robots; smart fabrics and adaptive interiors.
#   - Food and agriculture: hydroponic and soil-assisted systems using recycled water. Algae bioreactors supplement protein and oxygen.
#   - Energy: Solar arrays with energy storage; occasional compact nuclear or fusion microreactors to cover lunar night and dust storms.
# - Daily life:
#   - Citizens move through a gravity of 1/6 g; social norms reflect the unique life in reduced gravity and vacuum exposure.
#   - Education emphasizes lunar geology, space law, AI ethics, and engineering.
#   - Health care includes telemedicine with Earth-based specialists and autonomous medical robots. Radiation monitors and environmental sensors are ubiquitous.
# - Culture: A fusion of Earth’s diverse cultures with lunar adaptations. Public art often addresses themes of isolation, exploration, and the relationship between humans and the Moon.
#
# Security, defense, and risk
# - Threats: Solar flares and radiation storms, micrometeoroid impacts, dust, resource shortages, cyber threats, and political tensions between Earth and lunar factions.
# - Preparedness: Shielded emergency shelters; underground tunnels that double as evacuation routes; redundant life-support systems; detection networks and rapid-response teams.
# - Law enforcement: A Lunar Security Directorate handles policing, with special units trained for zero-g operations and rapid-response to surface incidents.
#
# History and timeline (outline you can adapt)
# - 21st century: Initial robotic exploration and the first permanent lunar outpost. Early ISRU experiments begin.
# - 22nd century: A network of settlements grows into a federation. Luna City emerges as the political and cultural capital.
# - 23rd century: Major reforms consolidate governance in Luna City; the Shield Dome District is developed; water ice mining becomes cornerstone of energy and life support.
# - 24th century: Interplanetary diplomacy centers on Luna City; advanced AI governance and autonomous infrastructure become mainstream.
# - Present concept: Luna City as a thriving, high-tech capital facing challenges of climate management, political balance, and cosmic expansion.
#
# Notable districts and landmarks (ideas you can name as you like)
# - The Council Atrium: where policy is debated, televised, and decided.
# - The Echo Archives: a vast digital and physical archive with recordings of lunar history and policy debates.
# - The Helio Dome: a giant solar harvesting dome supplying energy to the city.
# - The Icewell Quarter: houses polar water extraction facilities and ice storage.
# - The Skyport Complex: the main spaceport and interplanetary transfer hub.
# - The Lantern Market: a social hub for residents and visitors, blending lunar crafts and Earth imports.
#
# Character ideas (if you’re writing fiction)
# - The Prime Secretary: a seasoned administrator who navigates lunar politics and Earth interests.
# - The Archivist of Echoes: custodian of history and memory, preserving lunar culture.
# - The Shield Captain: head of security, balancing civil liberties with protection against external threats.
# - Ayoung Engineer: a brilliant ISRU expert who dreams of mining water from comets.
# - A Diplomat: negotiates lunar-mineral rights and Earth trade agreements.
#
# Plot hooks and world-building prompts
# - A water crisis threatens Luna City’s life-support systems, forcing a risky expedition to a distant ice source.
# - An Earth-backed corporation tries to rewrite lunar law to privatize the most valuable regolith resources, triggering political upheaval.
# - A solar flare damages key infrastructure, forcing the city to operate on emergency autonomy while rebuilding.
# - A cultural festival reveals tensions between traditional lunar communities and newer, technologically dependent residents.
#
# If you’d like, I can tailor this further:
# - For a hard sci‑fi tone with stricter physics and engineering realism.
# - For a cyberpunk vibe with corporate intrigue and underground networks.
# - For a utopian or dystopian mood, depending on the themes you want.
# - To fit a particular medium (novel, game setting, screenplay) and provide character bios, political diagrams, or location sketches.
# - To draft a concise one-page setting bible or a short scene set in Luna City.
#
# Would you like me to customize Luna City to a specific genre, time period, or narrative style? If you tell me your preferred tone and audience, I can generate a polished setting sheet, a map sketch description, and a sample scene.
